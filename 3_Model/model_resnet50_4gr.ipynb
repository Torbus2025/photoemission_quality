# %%
import h5py
import numpy as np
import torch
from torch.utils.data import Dataset
import pandas as pd
import torchvision.models as tv_models
import torch.nn as nn
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from tqdm import tqdm
import time
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from torchvision.ops import sigmoid_focal_loss

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: mps

# %%
class ARPESDataset(Dataset):

    def __init__(self, h5_path, labels=None, indices=None, transform=None):

        self.h5_path = h5_path
        self.labels = np.array(labels) if labels is not None else None

        with h5py.File(h5_path, "r", libver="latest", swmr=True) as f:
                data = f["entry/acquisition/data"]
                x = np.arange(data.shape[2])     

        self.indices = np.array(indices) if indices is not None else (
            np.arange(len(self.labels)) if self.labels is not None else None
        )

        if self.indices is None:
            with h5py.File(h5_path, "r", libver="latest", swmr=True) as f:
                data = f["entry/acquisition/data"]
                self.indices = np.arange(data.shape[2])   
                
        self.transform = transform

        self._file = None
        self._data = None

    def _init_file(self):
        if self._file is None:
            self._file = h5py.File(self.h5_path, "r", libver="latest", swmr=True)
            self._data = self._file["entry/acquisition/data"]

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, i):

        self._init_file()

        idx = self.indices[i]
        img = self._data[:, :, idx]

        if self.transform:
            img = self.transform(img)

        if not torch.is_tensor(img):
            img = torch.tensor(img, dtype=torch.float32)

        if img.ndim == 2:
            img = img.unsqueeze(0)
        elif img.ndim == 3 and img.shape[0] != 1:
            # already channel-first tensor
            pass

        label = torch.tensor(self.labels[idx], dtype=torch.long)

        return img, label

# %%
class ARPEStestDataset(Dataset):

    def __init__(self, h5_path, labels=None, indices=None, transform=None):

        self.h5_path = h5_path
        self.labels = np.array(labels) if labels is not None else None

        with h5py.File(h5_path, "r", libver="latest", swmr=True) as f:
                data = f["entry/acquisition/data"]
                x = np.arange(data.shape[2])     

        self.indices = np.array(indices) if indices is not None else (
            np.arange(len(self.labels)) if self.labels is not None else None
        )

        if self.indices is None:
            with h5py.File(h5_path, "r", libver="latest", swmr=True) as f:
                data = f["entry/acquisition/data"]
                self.indices = np.arange(data.shape[2])   
                
        self.transform = transform

        self._file = None
        self._data = None

    def _init_file(self):
        if self._file is None:
            self._file = h5py.File(self.h5_path, "r", libver="latest", swmr=True)
            self._data = self._file["entry/acquisition/data"]

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, i):

        self._init_file()

        idx = self.indices[i]
        img = self._data[:, :, idx]

        if self.transform:
            img = self.transform(img)

        if not torch.is_tensor(img):
            img = torch.tensor(img, dtype=torch.float32)

        if img.ndim == 2:
            img = img.unsqueeze(0)
        elif img.ndim == 3 and img.shape[0] != 1:
            # already channel-first tensor
            pass

        return img

# %%
class LogNormalize:
    def __call__(self, img):
        img = np.log1p(img.astype(np.float32))
        img = img - img.min()
        img = img / (img.max() + 1e-8)
        return img

# %%
import numpy as np
import random

class RandomEnergyWindowCrop:

    def __init__(self, e_min, e_max, window_width_eV):

        self.e_min = e_min
        self.e_max = e_max
        self.window_width_eV = window_width_eV

    def __call__(self, img):

        H, W = img.shape
        #print(f"Original image shape: {img.shape}")
        e_axis = np.linspace(self.e_min, self.e_max, H)

        center = random.uniform(
            self.e_min + self.window_width_eV/2,
            self.e_max - self.window_width_eV/2
        )

        half = self.window_width_eV / 2

        left = np.searchsorted(e_axis, center - half)
        right = np.searchsorted(e_axis, center + half)

        # print(
        #     f"E-range: "
        #     f"{e_axis[left]:.3f} eV -> "
        #     f"{e_axis[right-1]:.3f} eV"
        # )


        return img[left:right,:]

# %%
# crop spectra to defined energy window
class EnergyWindowCrop:

    def __init__(self, e_min, e_max):
        self.e_min = e_min
        self.e_max = e_max

    def __call__(self, img):
        H, W = img.shape
        #print(f"Original image shape: {img.shape}")
        e_axis = np.linspace(self.e_min, self.e_max, H)

        window_width_eV = self.e_max - self.e_min
        center = 6.45

        half = window_width_eV / 2

        left = np.searchsorted(e_axis, center - half)
        right = np.searchsorted(e_axis, center + half)

        # print(
        #     f"E-range: "
        #     f"{e_axis[left]:.3f} eV -> "
        #     f"{e_axis[right-1]:.3f} eV"
        # )

        return img[left:right,:]

# %%
from torchvision import transforms

transform = transforms.Compose([
    RandomEnergyWindowCrop(5.0, 6.8, window_width_eV=1.3),
    LogNormalize(),
    transforms.ToTensor(),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.Resize((288, 216))
])

transform_for_raw = transforms.Compose([
    EnergyWindowCrop(5.3, 6.6),
    LogNormalize(),
    transforms.ToTensor(),
    transforms.Resize((288, 216))
])

# %%
#labels_df = pd.read_csv('/Users/katharinasteinkirchner/Documents/Machine Learning/Classification_table.csv', delimiter=';', usecols=['Symmetrie', 'Resolution'])
labels_df_2 = pd.read_excel('/Users/katharinasteinkirchner/Documents/Machine Learning/Classification_table_Version2.xlsx', usecols=['Resolution'])
#labels_df_2 = pd.read_excel('/Users/atimm/Documents/ML/data/Classification_table_Version2.xlsx', usecols=['Resolution'])

#y = labels_df['Symmetrie'] * labels_df['Resolution']
y = labels_df_2['Resolution']

#großer Datensatz
h5_path = '/Users/katharinasteinkirchner/Documents/Machine Learning/x_y_grid_20260417_105734_020_z000000_snapshot_20260504_103607.h5'
#h5_path = '/Users/katharinasteinkirchner/Documents/Machine Learning/x_y_grid_20260417_105734_020_z000000_snapshot_20260504_103145.h5'
#h5_path = '/users/atimm/Documents/ML/data/x_y_grid_20260417_105734_020_z000000_snapshot_20260504_103145.h5'
with h5py.File(h5_path, "r", libver="latest", swmr=True) as f:
    data = f["entry/acquisition/data"]
    num_samples = data.shape[2]
    print(data.chunks)
# Out:
# (1440, 1080, 5)

# %%
from sklearn.model_selection import train_test_split
import numpy as np
from collections import Counter

indices = np.arange(len(y))

def safe_stratify(labels):
    counts = Counter(labels)
    if len(counts) == 0:
        return None
    return labels if min(counts.values()) >= 2 else None

# train_stratify = safe_stratify(y)
# train_idx, test_idx = train_test_split(
#     indices,
#     test_size=0.15, 
#     random_state=42,
#     stratify=train_stratify
# )

# val_stratify = safe_stratify(y[train_idx])
# train_idx, val_idx = train_test_split(
#     train_idx,
#     test_size=0.1765,
#     random_state=42,
#     stratify=val_stratify
# )


# variante ohne test set, nur train/val split
train_stratify = safe_stratify(y)
train_idx, val_idx = train_test_split(
    indices,
    test_size=0.15, 
    random_state=42,
    stratify=train_stratify
)

# %%
train_dataset = ARPESDataset(h5_path, y, train_idx, transform)
val_dataset   = ARPESDataset(h5_path, y, val_idx, transform)
#test_dataset  = ARPESDataset(h5_path, y, test_idx, transform)

full_dataset = ARPESDataset(h5_path, y, transform=transform_for_raw)
full_loader = DataLoader(full_dataset, batch_size=64, shuffle=False, num_workers=0, pin_memory=False)

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=0,
    pin_memory=False
)

val_loader = DataLoader(
    val_dataset,
    batch_size=32,
    shuffle=False,
    num_workers=0
)

# test_loader = DataLoader(
#     test_dataset,
#     batch_size=32,
#     shuffle=False,
#     num_workers=0
# )

fig, ax = plt.subplots(1, 10, figsize=(18, 3))
for i in range(10):
     img, label = train_dataset[i]
     ax[i].set_title(f"y={label.item()}")
     ax[i].axis("off")
     ax[i].imshow(img.squeeze(0))
plt.tight_layout()
plt.show()

# %%
import os
import certifi
from torchvision.models import resnet50, ResNet50_Weights

os.environ["SSL_CERT_FILE"] = certifi.where()

weights = ResNet50_Weights.IMAGENET1K_V1
model = resnet50(weights=weights)

# %%
import torch.nn as nn
import torchvision.models as tv_models
import numpy as np

# Load pretrained ResNet-50
model = tv_models.resnet50(pretrained=True)

# Modify first conv layer for grayscale input (1 channel)
model.conv1 = nn.Conv2d(
    1, 64,
    kernel_size=7,
    stride=2,
    padding=3,
    bias=False
)

# Number of features in final layer
num_ftrs = model.fc.in_features  # 2048 for ResNet-50

# Replace classification head
model.fc = nn.Sequential(
    nn.Dropout(p=0.7),
    nn.Linear(num_ftrs, len(np.unique(y)))
)

# Freeze all parameters
for param in model.parameters():
    param.requires_grad = False

# Unfreeze last 2 residual blocks + classifier
for param in model.layer3.parameters():
    param.requires_grad = True

for param in model.layer4.parameters():
    param.requires_grad = True

for param in model.fc.parameters():
    param.requires_grad = True


# Move to device
model = model.to(device)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
class_counts = np.bincount(y)

weights = len(y) / (len(class_counts) * class_counts)

print(weights)
# Out:
# [0.61072664 4.15294118 1.75621891 0.57119741 1.24734982]

# %%
# Optimizer: only params with requires_grad=True
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-5, weight_decay=1e-4)
#criterion = nn.CrossEntropyLoss()
#criterion = sigmoid_focal_loss
# LR scheduler (reduce LR on plateau of validation loss)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)


weights = torch.tensor(
    weights,
    dtype=torch.float32,
    device=device
)

criterion = nn.CrossEntropyLoss(
    weight=weights,label_smoothing=0.05
)

# %%
import matplotlib.pyplot as plt
import numpy as np


def plot_training_metrics(
    train_acc_history,
    val_acc_history,
    precision4_history,
    recall4_history,
    save_path=None
):
    """
    Plot Accuracy, Precision4 und Recall4 über die Epochen.
    """
    
    # Safety check for empty histories
    if not val_acc_history or not precision4_history:
        print("Warning: Training metrics are empty. Did training complete?")
        return

    epochs = np.arange(1, len(val_acc_history) + 1)

    fig, ax = plt.subplots(1, 2, figsize=(12, 5))

    # Accuracy
    ax[0].plot(
        epochs,
        train_acc_history,
        marker='o',
        linewidth=2,
        label='Train Accuracy'
    )

    ax[0].plot(
        epochs,
        val_acc_history,
        marker='s',
        linewidth=2,
        label='Validation Accuracy'
    )

    ax[0].set_xlabel('Epoch')
    ax[0].set_ylabel('Accuracy')
    ax[0].set_title('Accuracy')
    ax[0].grid(True, alpha=0.3)
    ax[0].legend()

    # Precision / Recall Klasse 4
    ax[1].plot(
        epochs,
        precision4_history,
        marker='o',
        linewidth=2,
        label='Precision (Class 4)'
    )

    ax[1].plot(
        epochs,
        recall4_history,
        marker='s',
        linewidth=2,
        label='Recall (Class 4)'
    )

    best_epoch = np.argmax(precision4_history) + 1

    ax[1].axvline(
        best_epoch,
        color='red',
        linestyle='--',
        alpha=0.7,
        label=f'Best Precision4 (Epoch {best_epoch})'
    )

    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('Score')
    ax[1].set_title('Class 4 Metrics')
    ax[1].grid(True, alpha=0.3)
    ax[1].legend()

    plt.tight_layout()

    if save_path is not None:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')

    plt.show()

# %%
# training version - plus precision/recall for class 4 and scheduler

# Debug: Show dataset sizes
#print(f"Train samples: {len(train_idx)}, Val samples: {len(val_idx)}, Test samples: {len(test_idx)}")
#print(f"Batches per epoch (train): {len(train_loader)}, (val): {len(val_loader)}")

print(f"Train samples: {len(train_idx)}, Val samples: {len(val_idx)}")
print(f"Batches per epoch (train): {len(train_loader)}, (val): {len(val_loader)}")

train_acc_history = []
val_acc_history = []

precision4_history = []
recall4_history = []

epochs_history = []

num_epochs = 60
best_precision4 = 0
visualize_once = True

for epoch in range(num_epochs):

    full_pred = []

    print(f"\nEpoch {epoch+1}/{num_epochs}")
    epoch_start = time.time()
    
    for phase in ['train', 'val']:

        tp4 = 0
        fp4 = 0
        fn4 = 0

        all_preds = []
        all_labels = []
        
        if phase == 'train':

            model.train()
            dataloader = train_loader

            # Visualize only in first epoch
            if visualize_once and epoch == 0:

                for x, z in dataloader:

                    fig, axes = plt.subplots(1, 6, figsize=(18, 3))

                    for i in range(6):

                        img = x[i, 0].cpu().numpy()
                        axes[i].imshow(img, aspect='auto', origin='lower', cmap='viridis')
                        axes[i].set_title(f"y={y[i].item()}")
                        axes[i].axis("off")

                    plt.tight_layout()
                    plt.show()

                    break

                visualize_once = False         

        else:

            model.eval()
            dataloader = val_loader

        running_loss = 0.0
        correct = 0
        total = 0

        for inputs, labels in tqdm(dataloader, desc=f"{phase} epoch {epoch+1}", leave=False):

            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                # harte Vorhersage (argmax)

                _, preds = torch.max(outputs, 1)
                pred_is4 = preds == 4
                label_is4 = labels == 4
                full_pred.extend(preds.cpu().numpy())

                # tp4 += (pred_is4 & label_is4).sum().item()
                # fp4 += (pred_is4 & ~label_is4).sum().item()
                # fn4 += (~pred_is4 & label_is4).sum().item()
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())

                if phase == 'train':
                    loss.backward()
                    optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        epoch_loss = running_loss / total
        epoch_acc = correct / total

        if phase == 'val':
            scheduler.step(epoch_loss)
        precision4 = precision_score(
            all_labels,
            all_preds,
            labels=[4],
            average='macro',
            zero_division=0
        )
        recall4 = recall_score(
            all_labels,
            all_preds,
            labels=[4],
            average='macro',
            zero_division=0
        )

        if phase == 'val' and precision4 > best_precision4:
            best_precision4 = precision4

            torch.save({
                "model_state_dict": model.state_dict(),
                "class_names": np.unique(y).tolist(),
                "transform": "LogNormalize + RandomEnergyWindowCrop",
            }, "arpes_resnet18_best.pt")

        print(
            f"{phase} "
            f"Loss={epoch_loss:.4f} "
            f"Acc={epoch_acc:.4f} "
            f"Precision4={precision4:.4f} "
            f"Recall4={recall4:.4f} "
            f"SchedulerLR={scheduler._last_lr[0]:.2e}"
        )

        # Append metrics to history
        if phase == 'train':
            train_acc_history.append(epoch_acc)
        else:
            val_acc_history.append(epoch_acc)
            precision4_history.append(precision4)
            recall4_history.append(recall4)

        # df = pd.DataFrame({'y_pred': full_pred})
        # df.to_csv('y_preds.csv', index=False)
# Out:
# Train samples: 1500, Val samples: 265
# Batches per epoch (train): 47, (val): 9
#
# Epoch 1/60
# train Loss=1.6114 Acc=0.2273 Precision4=0.2723 Recall4=0.5436 SchedulerLR=1.00e-05
# val Loss=1.7731 Acc=0.1585 Precision4=0.1585 Recall4=1.0000 SchedulerLR=1.00e-05
#
# Epoch 2/60
# train Loss=1.3448 Acc=0.3860 Precision4=0.3207 Recall4=0.7012 SchedulerLR=1.00e-05
# val Loss=1.2141 Acc=0.3774 Precision4=0.2770 Recall4=0.9762 SchedulerLR=1.00e-05
#
# Epoch 3/60
# train Loss=1.2264 Acc=0.4627 Precision4=0.3408 Recall4=0.6971 SchedulerLR=1.00e-05
# val Loss=1.0785 Acc=0.6000 Precision4=0.4457 Recall4=0.9762 SchedulerLR=1.00e-05
#
# Epoch 4/60
# train Loss=1.1129 Acc=0.5900 Precision4=0.4548 Recall4=0.7718 SchedulerLR=1.00e-05
# val Loss=1.0054 Acc=0.6642 Precision4=0.5139 Recall4=0.8810 SchedulerLR=1.00e-05
#
# Epoch 5/60
# train Loss=1.0765 Acc=0.6367 Precision4=0.5296 Recall4=0.8174 SchedulerLR=1.00e-05
# val Loss=0.9836 Acc=0.6642 Precision4=0.5135 Recall4=0.9048 SchedulerLR=1.00e-05
#
# Epoch 6/60
# train Loss=1.0264 Acc=0.6660 Precision4=0.5807 Recall4=0.8506 SchedulerLR=1.00e-05
# val Loss=0.9593 Acc=0.6868 Precision4=0.5143 Recall4=0.8571 SchedulerLR=1.00e-05
#
# Epoch 7/60
# train Loss=0.9972 Acc=0.6827 Precision4=0.6018 Recall4=0.8216 SchedulerLR=1.00e-05
# val Loss=0.9492 Acc=0.6830 Precision4=0.6140 Recall4=0.8333 SchedulerLR=1.00e-05
#
# Epoch 8/60
# train Loss=1.0011 Acc=0.7020 Precision4=0.6308 Recall4=0.8506 SchedulerLR=1.00e-05
# val Loss=0.9051 Acc=0.7132 Precision4=0.6792 Recall4=0.8571 SchedulerLR=1.00e-05
#
# Epoch 9/60
# train Loss=0.9636 Acc=0.7053 Precision4=0.6440 Recall4=0.8257 SchedulerLR=1.00e-05
# val Loss=0.9008 Acc=0.7019 Precision4=0.6034 Recall4=0.8333 SchedulerLR=1.00e-05
#
# Epoch 10/60
# train Loss=0.9451 Acc=0.7133 Precision4=0.6854 Recall4=0.8589 SchedulerLR=1.00e-05
# val Loss=0.9078 Acc=0.6981 Precision4=0.6167 Recall4=0.8810 SchedulerLR=1.00e-05
#
# Epoch 11/60
# train Loss=0.9207 Acc=0.7073 Precision4=0.6592 Recall4=0.8506 SchedulerLR=1.00e-05
# val Loss=0.8892 Acc=0.7094 Precision4=0.6491 Recall4=0.8810 SchedulerLR=1.00e-05
#
# Epoch 12/60
# train Loss=0.9147 Acc=0.7140 Precision4=0.6699 Recall4=0.8506 SchedulerLR=1.00e-05
# val Loss=0.8754 Acc=0.6868 Precision4=0.6230 Recall4=0.9048 SchedulerLR=1.00e-05
#
# Epoch 13/60
# train Loss=0.8961 Acc=0.7153 Precision4=0.6677 Recall4=0.8589 SchedulerLR=1.00e-05
# val Loss=0.8822 Acc=0.7208 Precision4=0.6800 Recall4=0.8095 SchedulerLR=1.00e-05
#
# Epoch 14/60
# train Loss=0.8816 Acc=0.7273 Precision4=0.6767 Recall4=0.8423 SchedulerLR=1.00e-05
# val Loss=0.8769 Acc=0.7208 Precision4=0.6066 Recall4=0.8810 SchedulerLR=1.00e-05
#
# Epoch 15/60
# train Loss=0.8866 Acc=0.7353 Precision4=0.6667 Recall4=0.8548 SchedulerLR=1.00e-05
# val Loss=0.8549 Acc=0.6906 Precision4=0.6140 Recall4=0.8333 SchedulerLR=1.00e-05
#
# Epoch 16/60
# train Loss=0.8766 Acc=0.7367 Precision4=0.6990 Recall4=0.8672 SchedulerLR=1.00e-05
# val Loss=0.8498 Acc=0.7057 Precision4=0.6167 Recall4=0.8810 SchedulerLR=1.00e-05
#
# Epoch 17/60
# train Loss=0.8652 Acc=0.7387 Precision4=0.7086 Recall4=0.8880 SchedulerLR=1.00e-05
# val Loss=0.8272 Acc=0.7283 Precision4=0.7500 Recall4=0.8571 SchedulerLR=1.00e-05
#
# Epoch 18/60
# train Loss=0.8400 Acc=0.7567 Precision4=0.7068 Recall4=0.9004 SchedulerLR=1.00e-05
# val Loss=0.8502 Acc=0.7283 Precision4=0.6607 Recall4=0.8810 SchedulerLR=1.00e-05
#
# Epoch 19/60
# train Loss=0.8410 Acc=0.7487 Precision4=0.6879 Recall4=0.8963 SchedulerLR=1.00e-05
# val Loss=0.8805 Acc=0.6906 Precision4=0.6667 Recall4=0.7619 SchedulerLR=1.00e-05
#
# Epoch 20/60
# train Loss=0.8218 Acc=0.7520 Precision4=0.7340 Recall4=0.8589 SchedulerLR=1.00e-05
# val Loss=0.8558 Acc=0.6755 Precision4=0.6364 Recall4=0.8333 SchedulerLR=1.00e-05
#
# Epoch 21/60
# train Loss=0.8280 Acc=0.7567 Precision4=0.7099 Recall4=0.8631 SchedulerLR=1.00e-05
# val Loss=0.8787 Acc=0.7094 Precision4=0.6667 Recall4=0.8571 SchedulerLR=5.00e-06
#
# Epoch 22/60
# train Loss=0.8052 Acc=0.7573 Precision4=0.7027 Recall4=0.8631 SchedulerLR=5.00e-06
# val Loss=0.8780 Acc=0.7019 Precision4=0.6140 Recall4=0.8333 SchedulerLR=5.00e-06
#
# Epoch 23/60
# train Loss=0.7886 Acc=0.7620 Precision4=0.7100 Recall4=0.8838 SchedulerLR=5.00e-06
# val Loss=0.8329 Acc=0.7434 Precision4=0.6909 Recall4=0.9048 SchedulerLR=5.00e-06
#
# Epoch 24/60
# train Loss=0.7943 Acc=0.7660 Precision4=0.7211 Recall4=0.8797 SchedulerLR=5.00e-06
# val Loss=0.8357 Acc=0.7094 Precision4=0.6167 Recall4=0.8810 SchedulerLR=5.00e-06
#
# Epoch 25/60
# train Loss=0.7921 Acc=0.7560 Precision4=0.7152 Recall4=0.8963 SchedulerLR=5.00e-06
# val Loss=0.8645 Acc=0.7245 Precision4=0.6923 Recall4=0.8571 SchedulerLR=2.50e-06
#
# Epoch 26/60
# train Loss=0.7970 Acc=0.7673 Precision4=0.7310 Recall4=0.8797 SchedulerLR=2.50e-06
# val Loss=0.8349 Acc=0.7358 Precision4=0.6607 Recall4=0.8810 SchedulerLR=2.50e-06
#
# Epoch 27/60
# train Loss=0.7674 Acc=0.7807 Precision4=0.7690 Recall4=0.8838 SchedulerLR=2.50e-06
# val Loss=0.8545 Acc=0.7094 Precision4=0.7292 Recall4=0.8333 SchedulerLR=2.50e-06
#
# Epoch 28/60
# train Loss=0.7796 Acc=0.7793 Precision4=0.7105 Recall4=0.8963 SchedulerLR=2.50e-06
# val Loss=0.8442 Acc=0.7472 Precision4=0.7660 Recall4=0.8571 SchedulerLR=2.50e-06
#
# Epoch 29/60
# train Loss=0.7714 Acc=0.7787 Precision4=0.7288 Recall4=0.8921 SchedulerLR=2.50e-06
# val Loss=0.8330 Acc=0.7321 Precision4=0.7143 Recall4=0.8333 SchedulerLR=1.25e-06
#
# Epoch 30/60
# train Loss=0.7685 Acc=0.7733 Precision4=0.7388 Recall4=0.8921 SchedulerLR=1.25e-06
# val Loss=0.8587 Acc=0.7094 Precision4=0.6981 Recall4=0.8810 SchedulerLR=1.25e-06
#
# Epoch 31/60
# train Loss=0.7461 Acc=0.7807 Precision4=0.7379 Recall4=0.8880 SchedulerLR=1.25e-06
# val Loss=0.8693 Acc=0.7208 Precision4=0.6379 Recall4=0.8810 SchedulerLR=1.25e-06
#
# Epoch 32/60
# train Loss=0.7888 Acc=0.7787 Precision4=0.7285 Recall4=0.8797 SchedulerLR=1.25e-06
# val Loss=0.8404 Acc=0.7170 Precision4=0.6852 Recall4=0.8810 SchedulerLR=1.25e-06
#
# Epoch 33/60
# train Loss=0.7855 Acc=0.7700 Precision4=0.7624 Recall4=0.8921 SchedulerLR=1.25e-06
# val Loss=0.8077 Acc=0.7547 Precision4=0.6545 Recall4=0.8571 SchedulerLR=1.25e-06
#
# Epoch 34/60
# train Loss=0.7836 Acc=0.7793 Precision4=0.7338 Recall4=0.8921 SchedulerLR=1.25e-06
# val Loss=0.8171 Acc=0.7358 Precision4=0.7200 Recall4=0.8571 SchedulerLR=1.25e-06
#
# Epoch 35/60
# train Loss=0.7588 Acc=0.7840 Precision4=0.7399 Recall4=0.9087 SchedulerLR=1.25e-06
# val Loss=0.8466 Acc=0.7245 Precision4=0.6667 Recall4=0.9048 SchedulerLR=1.25e-06
#
# Epoch 36/60
# train Loss=0.7574 Acc=0.7880 Precision4=0.7372 Recall4=0.8963 SchedulerLR=1.25e-06
# val Loss=0.8580 Acc=0.7132 Precision4=0.6364 Recall4=0.8333 SchedulerLR=1.25e-06
#
# Epoch 37/60
# train Loss=0.7806 Acc=0.7673 Precision4=0.6903 Recall4=0.8880 SchedulerLR=1.25e-06
# val Loss=0.8356 Acc=0.7283 Precision4=0.6852 Recall4=0.8810 SchedulerLR=6.25e-07
#
# Epoch 38/60
# train Loss=0.7581 Acc=0.7827 Precision4=0.7298 Recall4=0.8631 SchedulerLR=6.25e-07
# val Loss=0.8438 Acc=0.7585 Precision4=0.6863 Recall4=0.8333 SchedulerLR=6.25e-07
#
# Epoch 39/60
# train Loss=0.7627 Acc=0.7820 Precision4=0.7363 Recall4=0.8921 SchedulerLR=6.25e-07
# val Loss=0.8886 Acc=0.7170 Precision4=0.7115 Recall4=0.8810 SchedulerLR=6.25e-07
#
# Epoch 40/60
# train Loss=0.7545 Acc=0.7820 Precision4=0.7301 Recall4=0.8755 SchedulerLR=6.25e-07
# val Loss=0.8715 Acc=0.7321 Precision4=0.6981 Recall4=0.8810 SchedulerLR=6.25e-07
#
# Epoch 41/60
# train Loss=0.7586 Acc=0.7860 Precision4=0.7491 Recall4=0.9046 SchedulerLR=6.25e-07
# val Loss=0.8360 Acc=0.7434 Precision4=0.7347 Recall4=0.8571 SchedulerLR=3.13e-07
#
# Epoch 42/60
# train Loss=0.7523 Acc=0.7953 Precision4=0.7465 Recall4=0.8921 SchedulerLR=3.13e-07
# val Loss=0.8552 Acc=0.7283 Precision4=0.6981 Recall4=0.8810 SchedulerLR=3.13e-07
#
# Epoch 43/60
# train Loss=0.7394 Acc=0.8007 Precision4=0.7526 Recall4=0.8963 SchedulerLR=3.13e-07
# val Loss=0.8626 Acc=0.7434 Precision4=0.6852 Recall4=0.8810 SchedulerLR=3.13e-07
#
# Epoch 44/60
# train Loss=0.7800 Acc=0.7793 Precision4=0.7518 Recall4=0.8797 SchedulerLR=3.13e-07
# val Loss=0.8375 Acc=0.7208 Precision4=0.6667 Recall4=0.8571 SchedulerLR=3.13e-07
#
# Epoch 45/60
# train Loss=0.7619 Acc=0.7887 Precision4=0.7535 Recall4=0.9004 SchedulerLR=3.13e-07
# val Loss=0.8705 Acc=0.7283 Precision4=0.7391 Recall4=0.8095 SchedulerLR=1.56e-07
#
# Epoch 46/60
# train Loss=0.7755 Acc=0.7893 Precision4=0.7714 Recall4=0.8963 SchedulerLR=1.56e-07
# val Loss=0.8326 Acc=0.7358 Precision4=0.6852 Recall4=0.8810 SchedulerLR=1.56e-07
#
# Epoch 47/60
# train Loss=0.7611 Acc=0.7793 Precision4=0.7354 Recall4=0.8880 SchedulerLR=1.56e-07
# val Loss=0.8539 Acc=0.7358 Precision4=0.6923 Recall4=0.8571 SchedulerLR=1.56e-07
#
# Epoch 48/60
# train Loss=0.7497 Acc=0.7880 Precision4=0.7381 Recall4=0.9004 SchedulerLR=1.56e-07
# val Loss=0.8742 Acc=0.7547 Precision4=0.7200 Recall4=0.8571 SchedulerLR=1.56e-07
#
# Epoch 49/60
# train Loss=0.7559 Acc=0.7820 Precision4=0.7365 Recall4=0.9046 SchedulerLR=1.56e-07
# val Loss=0.8583 Acc=0.7358 Precision4=0.6792 Recall4=0.8571 SchedulerLR=7.81e-08
#
# Epoch 50/60
# train Loss=0.7589 Acc=0.7913 Precision4=0.7359 Recall4=0.8672 SchedulerLR=7.81e-08
# val Loss=0.8892 Acc=0.7208 Precision4=0.6167 Recall4=0.8810 SchedulerLR=7.81e-08
#
# Epoch 51/60
# train Loss=0.7596 Acc=0.7873 Precision4=0.7579 Recall4=0.8963 SchedulerLR=7.81e-08
# val Loss=0.8471 Acc=0.7283 Precision4=0.6545 Recall4=0.8571 SchedulerLR=7.81e-08
#
# Epoch 52/60
# train Loss=0.7476 Acc=0.7907 Precision4=0.7491 Recall4=0.8921 SchedulerLR=7.81e-08
# val Loss=0.8697 Acc=0.7208 Precision4=0.7200 Recall4=0.8571 SchedulerLR=7.81e-08
#
# Epoch 53/60
# train Loss=0.7608 Acc=0.7793 Precision4=0.7340 Recall4=0.8589 SchedulerLR=7.81e-08
# val Loss=0.8251 Acc=0.7132 Precision4=0.7447 Recall4=0.8333 SchedulerLR=3.91e-08
#
# Epoch 54/60
# train Loss=0.7292 Acc=0.8080 Precision4=0.7526 Recall4=0.9087 SchedulerLR=3.91e-08
# val Loss=0.8698 Acc=0.7283 Precision4=0.6491 Recall4=0.8810 SchedulerLR=3.91e-08
#
# Epoch 55/60
# train Loss=0.7373 Acc=0.7920 Precision4=0.7397 Recall4=0.8963 SchedulerLR=3.91e-08
# val Loss=0.8434 Acc=0.7170 Precision4=0.6604 Recall4=0.8333 SchedulerLR=3.91e-08
#
# Epoch 56/60
# train Loss=0.7566 Acc=0.7887 Precision4=0.7266 Recall4=0.8714 SchedulerLR=3.91e-08
# val Loss=0.8707 Acc=0.7283 Precision4=0.6379 Recall4=0.8810 SchedulerLR=3.91e-08
#
# Epoch 57/60
# train Loss=0.7513 Acc=0.7880 Precision4=0.7439 Recall4=0.8797 SchedulerLR=3.91e-08
# val Loss=0.8469 Acc=0.7283 Precision4=0.6842 Recall4=0.9286 SchedulerLR=1.95e-08
#
# Epoch 58/60
# train Loss=0.7350 Acc=0.7940 Precision4=0.7614 Recall4=0.9004 SchedulerLR=1.95e-08
# val Loss=0.8693 Acc=0.7170 Precision4=0.6364 Recall4=0.8333 SchedulerLR=1.95e-08
#
# Epoch 59/60
# train Loss=0.7353 Acc=0.7827 Precision4=0.7248 Recall4=0.8963 SchedulerLR=1.95e-08
# val Loss=0.8697 Acc=0.7057 Precision4=0.6604 Recall4=0.8333 SchedulerLR=1.95e-08
#
# Epoch 60/60
# train Loss=0.7780 Acc=0.7793 Precision4=0.7308 Recall4=0.8672 SchedulerLR=1.95e-08
# val Loss=0.8372 Acc=0.7434 Precision4=0.6727 Recall4=0.8810 SchedulerLR=1.95e-08

# %%
plot_training_metrics(
    train_acc_history,
    val_acc_history,
    precision4_history,
    recall4_history
)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

x = 57 # number of measurements (ARPES spectra) in x direction on sample

# predictions of model for all samples in dataset
y_pred_full = []
model.eval()
with torch.no_grad():
    for inputs, _ in full_loader:
        inputs = inputs.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        y_pred_full.extend(preds.cpu().numpy())

unique, counts = np.unique(y_pred_full, return_counts=True)

# Debug: Show predicted class distribution
print("Predicted class distribution:")
for u, c in zip(unique, counts):
    print(u, c)

arr = np.asarray(y_pred_full, dtype=float)
pad_len = (-len(arr)) % x
print(pad_len)
print(f"Total samples: {len(arr)}, Padded samples: {len(arr) + pad_len}")
arr_padded = np.pad(arr, (0, pad_len), constant_values=np.nan)
pred_matrix = arr_padded.reshape(-1, x)

true_matrix = np.asarray(y.cpu() if isinstance(y, torch.Tensor) else y, dtype=float)
pad_len_true = (-len(true_matrix)) % x
true_matrix_padded = np.pad(true_matrix, (0, pad_len_true), constant_values=np.nan)
true_matrix = true_matrix_padded.reshape(-1, x)

diff_matrix = pred_matrix - true_matrix

# Ground truth
ax = sns.heatmap(
    true_matrix,
    cmap='viridis',
    cbar=True
)
ax.invert_yaxis()
plt.title("Set labels")
plt.show() 

# Predictions
ax = sns.heatmap(
    pred_matrix,
    cmap='viridis',
    cbar=True
)
ax.invert_yaxis()
plt.title("Predicted labels")
plt.show()

# Differences
ax = sns.heatmap(
    diff_matrix,
    cmap='seismic',
    cbar=True
)
ax.invert_yaxis()
plt.title("Differences")
plt.show()
# Out:
# Predicted class distribution:
# 0 501
# 1 193
# 2 334
# 3 512
# 4 225
# 2
# Total samples: 1765, Padded samples: 1767

# %%
#h5_path_2 = "/Users/atimm/Documents/ML/data/Pos_map_20260526_161920_020_z000000_snapshot_20260526_174221_snapshot_20260616_135309.h5"
#h5_path_2 = "/Users/atimm/Documents/ML/data/Pos_map_20260526_161920_020_z000000_snapshot_20260526_174221_snapshot_20260616_135747.h5"
#h5_path_2 = "/Users/katharinasteinkirchner/Documents/Machine Learning/Pos_map_20260526_161920_020_z000000_snapshot_20260526_174221_snapshot_20260616_135747.h5"
h5_path_2 = '/Users/katharinasteinkirchner/Documents/Machine Learning/Pos_map_20260526_161920_020_z000000_snapshot_20260526_174221_snapshot_20260616_135309.h5'

with h5py.File(h5_path_2, "r", libver="latest", swmr=True) as f:
    data = f["entry/acquisition/data"]
    num_samples = data.shape[2]
    print(data.chunks)

full_dataset_2 = ARPEStestDataset(h5_path_2, transform=transform_for_raw)
full_loader_2 = DataLoader(full_dataset_2, batch_size=64, shuffle=False, num_workers=0, pin_memory=False)


x = 36 # number of measurements (ARPES spectra) in x direction on sample

# predictions of model for all samples in dataset
y_pred_full = []
model.eval()
with torch.no_grad():
    for inputs in full_loader_2:
        inputs = inputs.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        y_pred_full.extend(preds.cpu().numpy())

unique, counts = np.unique(y_pred_full, return_counts=True)

# Debug: Show predicted class distribution
print("Predicted class distribution:")
for u, c in zip(unique, counts):
    print(u, c)

arr = np.asarray(y_pred_full, dtype=float)
pad_len = (-len(arr)) % x
print(pad_len)
print(f"Total samples: {len(arr)}, Padded samples: {len(arr) + pad_len}")
arr_padded = np.pad(arr, (0, pad_len), constant_values=np.nan)
pred_matrix = arr_padded.reshape(-1, x)


# Predictions
ax = sns.heatmap(
    pred_matrix,
    cmap='viridis',
    cbar=True
)
ax.invert_yaxis()
plt.title("Predicted labels")
plt.show()
# Out:
# (720, 540, 10)
# Predicted class distribution:
# 0 366
# 1 4
# 2 926
# 0
# Total samples: 1296, Padded samples: 1296
